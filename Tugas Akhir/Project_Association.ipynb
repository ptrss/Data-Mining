# %% [markdown]
# ## Import Python Libraries

# %%
import numpy as np
import pandas as pd

from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ## Collecting Data

# %% [markdown]
# Dataset berasal dari Rekap Penjualan PT Arma Inti Raya (Banjarmasin) tahun 2017

# %%
data = pd.read_csv("Penjualan2017.csv")
print("Data shape", data.shape)
# Out:
# Data shape (1240, 9)

# %% [markdown]
# ## Explore Dataset

# %%
data.head()
# Out:
#    No   Tanggal     Invoice                     NamaPerusahaan  \
# 0   1  1/3/2017  16470599.0  PT. BERSAMA SEJAHTERA SAKTI (GAF)
# 1   2  1/3/2017  16470599.0  PT. BERSAMA SEJAHTERA SAKTI (GAF)
# 2   3  1/3/2017  16470599.0  PT. BERSAMA SEJAHTERA SAKTI (GAF)
# 3   4  1/3/2017  16470600.0           PT. SWADAYA ANDIKA (SLF)
# 4   5  1/3/2017  16470601.0  PT. BERSAMA SEJAHTERA SAKTI (GAF)
#
#                                 NamaBarang  Qty  Sat  HargaSatuan  JumlahHarga
# 0            OIL SEAL 120MM X 150MM X 14MM   10  PCS        46150       461500
# 1            OIL SEAL 130MM X 160MM X 13MM   10  PCS        43500       435000
# 2            OIL SEAL 150MM X 180MM X 14MM   10  PCS       152400      1524000
# 3             CAT HAMPLE TAHAN PANAS 600˚C   10   KG       250000      2500000
# 4  ATAP TRANSPARAN 0.8MM X 840MM X 6000MM    70  LBR       895000     62650000

# %%
# Eksplor kolom data
data.columns
# Out:
# Index(['No', 'Tanggal', 'Invoice', 'NamaPerusahaan', 'NamaBarang', 'Qty',
#        'Sat', 'HargaSatuan', 'JumlahHarga'],
#       dtype='object')

# %%
# Informasi data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1231 entries, 0 to 1239
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Invoice         1231 non-null   object
#  1   NamaPerusahaan  1231 non-null   object
#  2   NamaBarang      1231 non-null   object
#  3   Qty             1231 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 48.1+ KB

# %%
# Cek baris data yang tidak memiliki nomor nota
data.isnull().any()

# Dari informasi yang saya dapatkan, Invoice/Nota yang kosong dikarenakan pembelian secara tunai
# Out:
# No                False
# Tanggal           False
# Invoice            True
# NamaPerusahaan    False
# NamaBarang        False
# Qty               False
# Sat               False
# HargaSatuan       False
# JumlahHarga       False
# dtype: bool

# %% [markdown]
# ## Preprocessing Data

# %%
# Membersihkan extra white space
data['NamaPerusahaan'] = data['NamaPerusahaan'].str.strip()
data['NamaBarang'] = data['NamaBarang'].str.strip()

# Menghapus baris tanpa nomor Invoice/Nota
data.dropna(axis=0, subset=['Invoice'], inplace = True)
data['Invoice'] = data['Invoice'].astype('str').str.split('.').str[0]

# Memilih kolom yang akan digunakan
data = data[['Invoice', 'NamaPerusahaan', 'NamaBarang', 'Qty']]
data
# Out:
#        Invoice                       NamaPerusahaan  \
# 0     16470599    PT. BERSAMA SEJAHTERA SAKTI (GAF)
# 1     16470599    PT. BERSAMA SEJAHTERA SAKTI (GAF)
# 2     16470599    PT. BERSAMA SEJAHTERA SAKTI (GAF)
# 3     16470600             PT. SWADAYA ANDIKA (SLF)
# 4     16470601    PT. BERSAMA SEJAHTERA SAKTI (GAF)
# ...        ...                                  ...
# 1235   2634670    PT. CITRA PUTRA KEBUN ASRI (CPKA)
# 1236   2634670    PT. CITRA PUTRA KEBUN ASRI (CPKA)
# 1237   2634670    PT. CITRA PUTRA KEBUN ASRI (CPKA)
# 1238   2634671  PT. LADANG RUMPUN SUBUR ABADI (ASF)
# 1239   2634671  PT. LADANG RUMPUN SUBUR ABADI (ASF)
#
#                                   NamaBarang  Qty
# 0              OIL SEAL 120MM X 150MM X 14MM   10
# 1              OIL SEAL 130MM X 160MM X 13MM   10
# 2              OIL SEAL 150MM X 180MM X 14MM   10
# 3               CAT HAMPLE TAHAN PANAS 600˚C   10
# 4     ATAP TRANSPARAN 0.8MM X 840MM X 6000MM   70
# ...                                      ...  ...
# 1235              PACKING KARET 3MM (BENANG)    2
# 1236                 ORING 3MM (TAHAN PANAS)   10
# 1237              OIL SEAL TC 45 X 65 X 10MM    5
# 1238                      GLAND PACKING 3/8"    5
# 1239                 BOLT & NUT 7/8" X 8" CS   20
#
# [1231 rows x 4 columns]

# %%
basket_group = (data.groupby(['Invoice', 'NamaBarang'])['Qty']
                 .sum().unstack().reset_index().fillna(0)
                 .set_index('Invoice'))

pd.set_option('display.max_columns', 20)
basket_group
# Out:
# NamaBarang  ACRILIC 10 MM  ACRILIC DOP/BENING 2M X 1M TB 5  \
# Invoice
# 16470599              0.0                              0.0
# 16470600              0.0                              0.0
# 16470601              0.0                              0.0
# 16470602              0.0                              0.0
# 16470603              0.0                              0.0
# ...                   ...                              ...
# 5490169               0.0                              0.0
# 5490170               0.0                              0.0
# 5490171               0.0                              0.0
# 5490172               0.0                              0.0
# 5490173               0.0                              0.0
#
# NamaBarang  ACRILIC NAMA MEJA UKURAN F4 VERTICAL  \
# Invoice
# 16470599                                     0.0
# 16470600                                     0.0
# 16470601                                     0.0
# 16470602                                     0.0
# 16470603                                     0.0
# ...                                          ...
# 5490169                                      0.0
# 5490170                                      0.0
# 5490171                                      0.0
# 5490172                                      0.0
# 5490173                                      0.0
#
# NamaBarang  ACRILIC SHEET CLEAR 2000 X 1000 X 10MM  ADJUSTING CONE CB P15  \
# Invoice
# 16470599                                       0.0                    0.0
# 16470600                                       0.0                    0.0
# 16470601                                       0.0                    0.0
# 16470602                                       0.0                    0.0
# 16470603                                       0.0                    0.0
# ...                                            ...                    ...
# 5490169                                        0.0                    0.0
# 5490170                                        0.0                    0.0
# 5490171                                        0.0                    0.0
# 5490172                                        0.0                    0.0
# 5490173                                        0.0                    0.0
#
# NamaBarang  ADJUSTING CONE SHAFT P15  AIR CHUCK ALDO  \
# Invoice
# 16470599                         0.0             0.0
# 16470600                         0.0             0.0
# 16470601                         0.0             0.0
# 16470602                         0.0             0.0
# 16470603                         0.0             0.0
# ...                              ...             ...
# 5490169                          0.0             0.0
# 5490170                          0.0             0.0
# 5490171                          0.0             0.0
# 5490172                          0.0             0.0
# 5490173                          0.0             0.0
#
# NamaBarang  ALAT PEMBUKA BAN (LUMOS 3370)  ALLUMINIUM SULFAT  \
# Invoice
# 16470599                              0.0                0.0
# 16470600                              0.0                0.0
# 16470601                              0.0                0.0
# 16470602                              0.0                0.0
# 16470603                              0.0                0.0
# ...                                   ...                ...
# 5490169                               0.0                0.0
# 5490170                               0.0                0.0
# 5490171                               0.0                0.0
# 5490172                               0.0                0.0
# 5490173                               0.0                0.0
#
# NamaBarang  AMPEREMETER 1000A  ...  WEBBING SLING 2TON X 6M  \
# Invoice                        ...
# 16470599                  0.0  ...                      0.0
# 16470600                  0.0  ...                      0.0
# 16470601                  0.0  ...                      0.0
# 16470602                  0.0  ...                      0.0
# 16470603                  0.0  ...                      0.0
# ...                       ...  ...                      ...
# 5490169                   0.0  ...                      0.0
# 5490170                   0.0  ...                      0.0
# 5490171                   0.0  ...                      0.0
# 5490172                   0.0  ...                      0.0
# 5490173                   0.0  ...                      0.0
#
# NamaBarang  WELDING ELECTRODE S/S 308 L SIZE 2.6MM  \
# Invoice
# 16470599                                       0.0
# 16470600                                       0.0
# 16470601                                       0.0
# 16470602                                       0.0
# 16470603                                       0.0
# ...                                            ...
# 5490169                                        0.0
# 5490170                                        0.0
# 5490171                                        0.0
# 5490172                                        0.0
# 5490173                                        0.0
#
# NamaBarang  WELDING ELECTRODE S/S 308 L SIZE 3.2MM  \
# Invoice
# 16470599                                       0.0
# 16470600                                       0.0
# 16470601                                       0.0
# 16470602                                       0.0
# 16470603                                       0.0
# ...                                            ...
# 5490169                                        0.0
# 5490170                                        0.0
# 5490171                                        0.0
# 5490172                                        0.0
# 5490173                                        0.0
#
# NamaBarang  WELDING ELECTRODE S/S 309 L SIZE 2.6MM  \
# Invoice
# 16470599                                       0.0
# 16470600                                       0.0
# 16470601                                       0.0
# 16470602                                       0.0
# 16470603                                       0.0
# ...                                            ...
# 5490169                                        0.0
# 5490170                                        0.0
# 5490171                                        0.0
# 5490172                                        0.0
# 5490173                                        0.0
#
# NamaBarang  WELDING ELECTRODE S/S 309 L SIZE 3.2MM  \
# Invoice
# 16470599                                       0.0
# 16470600                                       0.0
# 16470601                                       0.0
# 16470602                                       0.0
# 16470603                                       0.0
# ...                                            ...
# 5490169                                        0.0
# 5490170                                        0.0
# 5490171                                        0.0
# 5490172                                        0.0
# 5490173                                        0.0
#
# NamaBarang  WELDING HOLDER (STANG LAS) 600A  WIRE MESH SS 304 10 X 1 X 1000MM  \
# Invoice
# 16470599                                0.0                               0.0
# 16470600                                0.0                               0.0
# 16470601                                0.0                               0.0
# 16470602                                0.0                               0.0
# 16470603                                0.0                               0.0
# ...                                     ...                               ...
# 5490169                                 0.0                               0.0
# 5490170                                 0.0                               0.0
# 5490171                                 0.0                               0.0
# 5490172                                 0.0                               0.0
# 5490173                                 0.0                               0.0
#
# NamaBarang  WIRE SCAFFOLDING 2MM  Y STRAINER MERK : YONE C1 DN 100 PN 16  \
# Invoice
# 16470599                     0.0                                     0.0
# 16470600                     0.0                                     0.0
# 16470601                     0.0                                     0.0
# 16470602                     0.0                                     1.0
# 16470603                     0.0                                     0.0
# ...                          ...                                     ...
# 5490169                      0.0                                     0.0
# 5490170                      0.0                                     0.0
# 5490171                      0.0                                     0.0
# 5490172                      0.0                                     0.0
# 5490173                      0.0                                     0.0
#
# NamaBarang  ZELIO LOGIC SR 2B121 FU
# Invoice
# 16470599                        0.0
# 16470600                        0.0
# 16470601                        0.0
# 16470602                        0.0
# 16470603                        0.0
# ...                             ...
# 5490169                         0.0
# 5490170                         0.0
# 5490171                         0.0
# 5490172                         0.0
# 5490173                         0.0
#
# [609 rows x 1055 columns]

# %%
# Membuat method hot_encode untuk mengubah jumlah beli menjadi membeli(1) atau tidak(0)
def hot_encode(x):
    if(x <= 0):
        return 0
    if(x > 0):
        return 1

# %%
# Menerapkan funtion hot_encode
basket_group = basket_group.applymap(hot_encode)
basket_group

# DistribusiBarang = TransactionEncoder().fit_transform(data)
# Out:
# NamaBarang  ACRILIC 10 MM  ACRILIC DOP/BENING 2M X 1M TB 5  \
# Invoice
# 16470599                0                                0
# 16470600                0                                0
# 16470601                0                                0
# 16470602                0                                0
# 16470603                0                                0
# ...                   ...                              ...
# 5490169                 0                                0
# 5490170                 0                                0
# 5490171                 0                                0
# 5490172                 0                                0
# 5490173                 0                                0
#
# NamaBarang  ACRILIC NAMA MEJA UKURAN F4 VERTICAL  \
# Invoice
# 16470599                                       0
# 16470600                                       0
# 16470601                                       0
# 16470602                                       0
# 16470603                                       0
# ...                                          ...
# 5490169                                        0
# 5490170                                        0
# 5490171                                        0
# 5490172                                        0
# 5490173                                        0
#
# NamaBarang  ACRILIC SHEET CLEAR 2000 X 1000 X 10MM  ADJUSTING CONE CB P15  \
# Invoice
# 16470599                                         0                      0
# 16470600                                         0                      0
# 16470601                                         0                      0
# 16470602                                         0                      0
# 16470603                                         0                      0
# ...                                            ...                    ...
# 5490169                                          0                      0
# 5490170                                          0                      0
# 5490171                                          0                      0
# 5490172                                          0                      0
# 5490173                                          0                      0
#
# NamaBarang  ADJUSTING CONE SHAFT P15  AIR CHUCK ALDO  \
# Invoice
# 16470599                           0               0
# 16470600                           0               0
# 16470601                           0               0
# 16470602                           0               0
# 16470603                           0               0
# ...                              ...             ...
# 5490169                            0               0
# 5490170                            0               0
# 5490171                            0               0
# 5490172                            0               0
# 5490173                            0               0
#
# NamaBarang  ALAT PEMBUKA BAN (LUMOS 3370)  ALLUMINIUM SULFAT  \
# Invoice
# 16470599                                0                  0
# 16470600                                0                  0
# 16470601                                0                  0
# 16470602                                0                  0
# 16470603                                0                  0
# ...                                   ...                ...
# 5490169                                 0                  0
# 5490170                                 0                  0
# 5490171                                 0                  0
# 5490172                                 0                  0
# 5490173                                 0                  0
#
# NamaBarang  AMPEREMETER 1000A  ...  WEBBING SLING 2TON X 6M  \
# Invoice                        ...
# 16470599                    0  ...                        0
# 16470600                    0  ...                        0
# 16470601                    0  ...                        0
# 16470602                    0  ...                        0
# 16470603                    0  ...                        0
# ...                       ...  ...                      ...
# 5490169                     0  ...                        0
# 5490170                     0  ...                        0
# 5490171                     0  ...                        0
# 5490172                     0  ...                        0
# 5490173                     0  ...                        0
#
# NamaBarang  WELDING ELECTRODE S/S 308 L SIZE 2.6MM  \
# Invoice
# 16470599                                         0
# 16470600                                         0
# 16470601                                         0
# 16470602                                         0
# 16470603                                         0
# ...                                            ...
# 5490169                                          0
# 5490170                                          0
# 5490171                                          0
# 5490172                                          0
# 5490173                                          0
#
# NamaBarang  WELDING ELECTRODE S/S 308 L SIZE 3.2MM  \
# Invoice
# 16470599                                         0
# 16470600                                         0
# 16470601                                         0
# 16470602                                         0
# 16470603                                         0
# ...                                            ...
# 5490169                                          0
# 5490170                                          0
# 5490171                                          0
# 5490172                                          0
# 5490173                                          0
#
# NamaBarang  WELDING ELECTRODE S/S 309 L SIZE 2.6MM  \
# Invoice
# 16470599                                         0
# 16470600                                         0
# 16470601                                         0
# 16470602                                         0
# 16470603                                         0
# ...                                            ...
# 5490169                                          0
# 5490170                                          0
# 5490171                                          0
# 5490172                                          0
# 5490173                                          0
#
# NamaBarang  WELDING ELECTRODE S/S 309 L SIZE 3.2MM  \
# Invoice
# 16470599                                         0
# 16470600                                         0
# 16470601                                         0
# 16470602                                         0
# 16470603                                         0
# ...                                            ...
# 5490169                                          0
# 5490170                                          0
# 5490171                                          0
# 5490172                                          0
# 5490173                                          0
#
# NamaBarang  WELDING HOLDER (STANG LAS) 600A  WIRE MESH SS 304 10 X 1 X 1000MM  \
# Invoice
# 16470599                                  0                                 0
# 16470600                                  0                                 0
# 16470601                                  0                                 0
# 16470602                                  0                                 0
# 16470603                                  0                                 0
# ...                                     ...                               ...
# 5490169                                   0                                 0
# 5490170                                   0                                 0
# 5490171                                   0                                 0
# 5490172                                   0                                 0
# 5490173                                   0                                 0
#
# NamaBarang  WIRE SCAFFOLDING 2MM  Y STRAINER MERK : YONE C1 DN 100 PN 16  \
# Invoice
# 16470599                       0                                       0
# 16470600                       0                                       0
# 16470601                       0                                       0
# 16470602                       0                                       1
# 16470603                       0                                       0
# ...                          ...                                     ...
# 5490169                        0                                       0
# 5490170                        0                                       0
# 5490171                        0                                       0
# 5490172                        0                                       0
# 5490173                        0                                       0
#
# NamaBarang  ZELIO LOGIC SR 2B121 FU
# Invoice
# 16470599                          0
# 16470600                          0
# 16470601                          0
# 16470602                          0
# 16470603                          0
# ...                             ...
# 5490169                           0
# 5490170                           0
# 5490171                           0
# 5490172                           0
# 5490173                           0
#
# [609 rows x 1055 columns]

# %% [markdown]
# ## Modelling

# %%
# Membangun model menggunakan algoritme Apriori
frq_items = apriori(basket_group, min_support = 0.002, use_colnames=True)

# Membentuk aturan-aturan asosiasi
rules = association_rules(frq_items, metric="confidence", min_threshold=0.3)
rules = rules.sort_values(['confidence', 'lift'], ascending=[False, False])
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %% [markdown]
# ### Top 5 Apriori

# %%
rules.head(5)
# Out:
#                      antecedents                   consequents  \
# 0   (SODA ASH, POWDER, KARUNGAN)           (ALLUMINIUM SULFAT)
# 1            (ALLUMINIUM SULFAT)  (SODA ASH, POWDER, KARUNGAN)
# 10          (BELTING B 75 BANDO)          (BELTING B 85 BANDO)
# 11          (BELTING B 85 BANDO)          (BELTING B 75 BANDO)
# 16        (BOLT & NUT 3/4" X 3")        (BOLT & NUT 5/8" X 3")
#
#     antecedent support  consequent support   support  confidence   lift  \
# 0             0.003284            0.003284  0.003284         1.0  304.5
# 1             0.003284            0.003284  0.003284         1.0  304.5
# 10            0.003284            0.003284  0.003284         1.0  304.5
# 11            0.003284            0.003284  0.003284         1.0  304.5
# 16            0.003284            0.003284  0.003284         1.0  304.5
#
#     leverage  conviction  zhangs_metric
# 0   0.003273         inf            1.0
# 1   0.003273         inf            1.0
# 10  0.003273         inf            1.0
# 11  0.003273         inf            1.0
# 16  0.003273         inf            1.0

# %% [markdown]
# ### Bottom 5 Apriori

# %%
rules.tail(5)
# Out:
#                                 antecedents               consequents  \
# 19                   (BOLT & NUT 3/8" X 1")    (BOLT & NUT 3/4" X 4")
# 2   (BATU GERINDA POTONG 4" 100 X 1 X 16MM)       (AMPLAS KERTAS 800)
# 4                         (BATU GERINDA 4")         (ANTI KARAT WD40)
# 6                         (BATU GERINDA 4")         (BATU GERINDA 6")
# 8                         (BATU GERINDA 4")  (BATU GERINDA POTONG 4")
#
#     antecedent support  consequent support   support  confidence        lift  \
# 19            0.004926            0.004926  0.003284    0.666667  135.333333
# 2             0.006568            0.003284  0.003284    0.500000  152.250000
# 4             0.008210            0.003284  0.003284    0.400000  121.800000
# 6             0.008210            0.003284  0.003284    0.400000  121.800000
# 8             0.008210            0.003284  0.003284    0.400000  121.800000
#
#     leverage  conviction  zhangs_metric
# 19  0.003260    2.985222       0.997525
# 2   0.003263    1.993432       1.000000
# 4   0.003257    1.661193       1.000000
# 6   0.003257    1.661193       1.000000
# 8   0.003257    1.661193       1.000000
